# %% [markdown]
# ![PPGI_UFRJ](imagens/ppgi-ufrj.png)
# # Fundamentos de Ciência de Dados

# %% [markdown]
# ---
# # PPGI/UFRJ 2020.3
#
# ## Prof Sergio Serra e Jorge Zavaleta

# %% [markdown]
# ---
# ## Data Provenance em Python
#
# ### This repository is a demo. It part of my classes at PPGI/UFRJ - 2020.3.
#
# > #### It aims to be an Interactive and Reproducible Experiment Enriched with  Data Provenance  - Powered by Zenodo and Binder.

# %% [markdown]
# # 0 - Prepare your source code and Jupyter Nottebok

# %% [markdown]
# # 1- Saving your Jupyter notebook and outputs (with PROV!)

# %% [markdown]
# ## 1.1 - The Deposit Requirements are:
#
# ### Minimally required files:
#
# 1.  Save the notebook .ipynb (cells run with results viewable)
# 2. Create a README and LICENSE (.txt)
#
#
# ### Addttional files:
#
# 1. Save/Create the .md file
# 2. Save/Create the reST file
# 3. Dataset and provenance files
#
# ## 1.1.1 - Create CodeMeta.json file
#
# ***Prepare the CodeMeta***
#
#     https://codemeta.github.io/codemeta-generator/
#
# ![image-6.png](attachment:image-6.png)
#
# ***Download the .json file***
#
# ## 1.1.2 - Create Citation file
#
# ***Prepare the Citation***
#
#     https://citation-file-format.github.io/cff-initializer-javascript
#
# ![image-7.png](attachment:image-7.png)
#
# ***Download the .ctt file***

# %% [markdown]
# ## 2 - Create your GitHub (if you do not have), otherwise Log In)

# %% [markdown]
# ### 2.1 Create a new repository
#
# 1. Especify the Repository Name
# 2. Add a Description (optional)
# 3. Choose the type of repository, choose **Public**, so anyone on the internet can see this repository.
# 4. Do not forget to initializar the repository README and LICENSE files
#
#     Check README file and LICENSE (choose the license type --> CC0 1.0 Universal (CC0 1.0) Public Domain Dedication
#
#
# 5. Push **Create Repository** Button
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.2 Add README content (README.md)
#
# 1. Click in the pencil icon to Edit it (right below the file list), add extra comments.
#
# ***OBS*** *Its is a markdown file, you can format as you wish. to see the output press Preview Changes*
#
# 2. At the bottom of the page. Push **Commit changes** buttom
#
# ***OBS*** *We suggest Commit directly to the main branch*
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 2.3 Upload Notebook contents into GitHub
#
# 1. Return to your repository, push ***Add File*** Button and select ***Upload Files**
# 2. You can drag or choose all files you want to share
#
# ***OBS*** *Dont forget to upload all mandatory and optional files you want to share (as describesd in step 1).
# - Jupyter Files (.ipynb, .md, .zip)
#
# - Dataset and provenance outputs
#
# 3. At the bottom of the page. Push **Commit changes** buttom
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3 - Create a Zenodo account  (if you do not have), otherwise Log In)

# %% [markdown]
# Zenodo is a general-purpose open-access repository developed under the European OpenAIRE program and operated by CERN. It allows researchers to deposit research papers, data sets, research software, reports, and any other research related digital artifacts. For each submission, a persistent digital object identifier (DOI) is minted, which makes the stored items easily citeable.
#
# `<Zenodo>` : <https://zenodo.org/login/?next=%2F>
#
# ![image-5.png](attachment:image-5.png) > Login

# %% [markdown]
# ## 3.1 Connect Zenodo to GitHub
#
# 1. Select **GitHub** in Zenodo´s Popup Menu (See picture below!)
#
# ![image.png](attachment:image.png)>Logged In
#
# 2. Follow the following steps in Zenodo
#
# 3. Toggle the switch to **ON** on the repository you want automatic preservation of your software
#
# 4. Create a release! You must return to GitHub and create a release. Zenodo will automatically download a .zip-ball of each new release and register a DOI.
#
# 5. Select (or Drag and Drop) the binaries you want to release.
#
# 7. Do not forget the insert a tag
#
# 6. To create the relase push **Create a new release** in GitHub (link is at the right side of your repository), in the following windows push ** Publish release** at the bottom left.
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## 3. Create a (Free) Zenodo DOI
#
# Return to Zenodo, notice that after the release was published in GiuHub, a DOI badge was automatically created. Now you can include in GitHub README will appear next to your repository below.
#
# ![image.png](attachment:image.png)
#
# 1. Click in the **DOI badge** and noite the links
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4 - Create your Binder-ready repository on GitHub (if you do not have), otherwise Log In)

# %% [markdown]
# A Binder (also called a Binder-ready repository) is a **code repository that contains at least two things:**
#
# 1. **Code or content that you’d like people to run.** This might be a Jupyter Notebook that explains an idea, or an R script that makes a visualization.
#
# 2. **Configuration files for your environment.** These files are used by Binder to build the environment needed to run your code. For a list of all configuration files available, see the Configuration Files page.
#
# A Binder repository can be built by a BinderHub, which will generate a link that you can share with others, allowing them to interact with the content in your repository.
#
# `<Binder>` : <https://mybinder.org/>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.1 Create your Binder-ready repository on GitHub
#
# Binder uses pre-existing best practices in data science in order to infer and build the environment needed for your repository
#
# #### 4.1.1 - To make a repository Binder-ready, follow the instructions in the Binder docs.
#
# `<Binder>` : <https://mybinder.readthedocs.io/en/latest/introduction.html>
#
# - A  Go to https://mybinder.org.
# - B  You will see a form that asks you to specify a repository for mybinder.org to build.
#
# ![image.png](attachment:image.png)
#
# - 1 In the first field, select ZENODO DOI
#
# - 2 Notice that appears the DOI you have created in the previous stepes. Copy the DOI and paste in the first field
#
# For instance, in our case we paste **10.5281/zenodo.4553669**
#
# - 2 Click the **Launch button**
#     This will ask mybinder.org to build the environment needed to run the repository. You can click on the “Build logs” button to see the logs generated by the build process.
#
# - 3 While your Binder repository is building, note the URL that points to your unique Binder.
#
# - 4 You can share this URL with a friend, allowing them to access an interactive version of your code repository.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 4.1.2 - After the Binding-Publishing you got a citable and Reproductible Jupyter notebook on the web
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# #### Fundamentos de Ciência de Dados &copy; Copyright 2021, Sergio Serra & Jorge Zavaleta
